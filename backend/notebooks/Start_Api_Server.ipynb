# %%
import sys
sys.path.insert(0, '/Workspace/Users/2023itb027.nikhil@students.iiests.ac.in/Intelligent-Doc-Parser-DATABRICKS-')
sys.path.insert(0, '/Workspace/Users/2023itb027.nikhil@students.iiests.ac.in/Intelligent-Doc-Parser-DATABRICKS-/backend')

# %pip install -r /Workspace/Users/2023itb027.nikhil@students.iiests.ac.in/Intelligent-Doc-Parser-DATABRICKS-/backend/requirements.txt

dbutils.library.restartPython()

# %%
import sys
sys.path.insert(0, '/Workspace/Users/2023itb027.nikhil@students.iiests.ac.in/Intelligent-Doc-Parser-DATABRICKS-')
sys.path.insert(0, '/Workspace/Users/2023itb027.nikhil@students.iiests.ac.in/Intelligent-Doc-Parser-DATABRICKS-/backend')

# Uninstall incompatible langchain and reinstall compatible versions
# %pip uninstall -y langchain langchain-core langchain-openai
# %pip install 'langchain<1.0' 'langchain-core<1.0' 'langchain-openai<0.2'

dbutils.library.restartPython()

# %%
import os

# Configure API key using Databricks Secrets
# First, create a secret scope and add your Groq API key:
#   1. Create scope: databricks secrets create-scope --scope my-secrets
#   2. Add key: databricks secrets put --scope my-secrets --key groq-api-key
#   3. Paste your actual Groq API key when prompted

os.environ['GROQ_API_KEY'] = dbutils.secrets.get(scope='my-secrets', key='groq-api-key')

print("✓ API key configured successfully from Databricks Secrets")

# %%
import sys
sys.path.insert(0, '/Workspace/Users/2023itb027.nikhil@students.iiests.ac.in/Intelligent-Doc-Parser-DATABRICKS-')
sys.path.insert(0, '/Workspace/Users/2023itb027.nikhil@students.iiests.ac.in/Intelligent-Doc-Parser-DATABRICKS-/backend')

# Execute the FastAPI server
with open('/Workspace/Users/2023itb027.nikhil@students.iiests.ac.in/Intelligent-Doc-Parser-DATABRICKS-/backend/api/main.py', 'r') as f:
    exec(f.read())
